# %%
# Importar as libraries essenciais
import matplotlib.pyplot as plt
import matplotlib.animation as animation
import numpy as np
import seaborn as sns
sns.set_style("white")
import pandas as pd
my_dpi=96

# %%
# Abrir os dados do csv. alojados na web
url = 'https://python-graph-gallery.com/wp-content/uploads/gapminderData.csv'
data = pd.read_csv(url)
#data=pd.read_csv('gapminderData.csv')
data.head()
# Out:
#        country  year         pop continent  lifeExp   gdpPercap
# 0  Afghanistan  1952   8425333.0      Asia   28.801  779.445314
# 1  Afghanistan  1957   9240934.0      Asia   30.332  820.853030
# 2  Afghanistan  1962  10267083.0      Asia   31.997  853.100710
# 3  Afghanistan  1967  11537966.0      Asia   34.020  836.197138
# 4  Afghanistan  1972  13079460.0      Asia   36.088  739.981106

# %%
# Transforma a coluna de nome "Continent" para valores numéricos
data['continent']=pd.Categorical(data['continent'])

# %%
anos=data.year.unique()

# %%
# %matplotlib notebook
# %matplotlib notebook

# Iniciar a figura
#fig=plt.figure(figsize=(680/my_dpi, 480/my_dpi), dpi=my_dpi)
fig, ax = plt.subplots(figsize=(680/my_dpi, 480/my_dpi), dpi=my_dpi)

# Definir os títulos para os eixos x e y, bem como as escalas e o limite dos mesmos
plt.yscale('log')
plt.xlabel("Life Expectancy")
plt.ylabel("GDP per Capita")
plt.ylim(100,100000)
plt.xlim(30, 90)

# Definir as animações do gráfico
def animate(i):
    plt.title("Year: "+str(anos[i]) )
    tmp=data[ data.year == anos[i] ]
    scut=plt.scatter(tmp['lifeExp'], tmp['gdpPercap'] , s=tmp['pop']/200000 , c=tmp['continent'].cat.codes, cmap="Accent", alpha=0.6, edgecolors="white", linewidth=2)
    #scut=ax.scatter(tmp['lifeExp'], tmp['gdpPercap'] , s=tmp['pop']/200000 , c=tmp['continent'].cat.codes, cmap="Accent", alpha=0.6, edgecolors="white", linewidth=2)

    
# Definir as características da animação    
ani = animation.FuncAnimation(fig, animate, frames=len(anos), interval=200, blit=False, repeat=False)

#Definir a legenda
scatter, = plt.plot([1,2,3], label='Asia')
scatter, = plt.plot([1,2,3], label='Europe')
scatter, = plt.plot([1,2,3], label='Americas')
scatter, = plt.plot([1,2,3], label='Africa')
scatter, = plt.plot([1,2,3], label='Oceania')
plt.legend(loc='upper left')

# Apresentar o gráfico final
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="680">
